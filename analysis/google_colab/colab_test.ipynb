# %%
import sys
from pathlib import Path
import numpy as np

sys.path.append(str(Path.cwd().parent / "bayesian_order_based_learning"))
from simulation import Simulation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1707/956810765.py in <cell line: 0>()
#       4
#       5 sys.path.append(str(Path.cwd().parent / "bayesian_order_based_learning"))
# ----> 6 from simulation import Simulation
#
# ModuleNotFoundError: No module named 'simulation'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !git clone https://github.com/sreeharimr2005/bayesian-multi-dag.git
# Out:
# Cloning into 'bayesian-multi-dag'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 90 (delta 38), reused 62 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (90/90), 28.14 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# %cd bayesian-multi-dag/bay
# Out:
# /content/bayesian-multi-dag

# %%
# !pip install -e .
